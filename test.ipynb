# %%
import numpy as np
from env.quad3d import Quad3DEnv
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
env = Quad3DEnv()
obs, _ = env.reset(options={
    "init_px": 0.0,
    "init_py": 0.0,
    "init_pz": -0.3,
    "init_vx": 0.0,
    "init_vy": 0.0,
    "init_vz": 0.0,
    "init_phi": 0.0,
    "init_theta": 0.0,
    "init_psi": 0.0,
})

for t in range(500):
    obs, r, c, terminated, truncated, info = env.step(np.zeros(4))
    if terminated or truncated:
        print(t, terminated, truncated, info)
        break
# Out:
# 499 False True {'h': -0.30000001192092896, 'cost': 0.0, 'cost_dense': -0.30000001192092896, 'binary_cost': 0.0, 'pz': -0.30000001192092896, 'state_norm': 0.30000001192092896, 'terminated': False, 'truncated': True, 'episode_reward': -450.00001788139343, 'episode_cost': 0.0, 'episode_length': 500}
